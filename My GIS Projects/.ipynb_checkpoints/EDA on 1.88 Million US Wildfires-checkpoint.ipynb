# %%
import findspark
import contextily as ctx
import matplotlib.pyplot as plt
from pyspark.sql.functions import col

# %%
findspark.init("/home/danial/spark-3.4.0-bin-hadoop3")

# %%
from pyspark.sql import SparkSession

# %%
# To startup the SparkSession with JDBC driver (required to interact with SQLite databases using Spark)

spark = SparkSession.builder.config('spark.jars.packages', 'org.xerial:sqlite-jdbc:3.42.0.0').getOrCreate()
# Out:
# 23/06/05 19:37:01 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df_spark = spark.read.format('jdbc').options(driver='org.sqlite.JDBC', \
                                             inferSchema = True,\
                                             header = True,\
                                             dbtable = 'fires',\
                                             url= 'jdbc:sqlite:/home/danial/Desktop/mygis/Geospatial_Data_Science/My GIS Projects/data/3.1.88_M_US_Wildfires/FPA_FOD_20170508.sqlite').load()

# %%
df_spark.printSchema()
# Out:
# root
#  |-- OBJECTID: integer (nullable = true)
#  |-- FOD_ID: decimal(38,18) (nullable = true)
#  |-- FPA_ID: string (nullable = true)
#  |-- SOURCE_SYSTEM_TYPE: string (nullable = true)
#  |-- SOURCE_SYSTEM: string (nullable = true)
#  |-- NWCG_REPORTING_AGENCY: string (nullable = true)
#  |-- NWCG_REPORTING_UNIT_ID: string (nullable = true)
#  |-- NWCG_REPORTING_UNIT_NAME: string (nullable = true)
#  |-- SOURCE_REPORTING_UNIT: string (nullable = true)
#  |-- SOURCE_REPORTING_UNIT_NAME: string (nullable = true)
#  |-- LOCAL_FIRE_REPORT_ID: string (nullable = true)
#  |-- LOCAL_INCIDENT_ID: string (nullable = true)
#  |-- FIRE_CODE: string (nullable = true)
#  |-- FIRE_NAME: string (nullable = true)
#  |-- ICS_209_INCIDENT_NUMBER: string (nullable = true)
#  |-- ICS_209_NAME: string (nullable = true)
#  |-- MTBS_ID: string (nullable = true)
#  |-- MTBS_FIRE_NAME: string (nullable = true)
#  |-- COMPLEX_NAME: string (nullable = true)
#  |-- FIRE_YEAR: decimal(38,18) (nullable = true)
#  |-- DISCOVERY_DATE: decimal(38,18) (nullable = true)
#  |-- DISCOVERY_DOY: decimal(38,18) (nullable = true)
#  |-- DISCOVERY_TIME: string (nullable = true)
#  |-- STAT_CAUSE_CODE: decimal(38,18) (nullable = true)
#  |-- STAT_CAUSE_DESCR: string (nullable = true)
#  |-- CONT_DATE: decimal(38,18) (nullable = true)
#  |-- CONT_DOY: decimal(38,18) (nullable = true)
#  |-- CONT_TIME: string (nullable = true)
#  |-- FIRE_SIZE: decimal(38,18) (nullable = true)
#  |-- FIRE_SIZE_CLASS: string (nullable = true)
#  |-- LATITUDE: decimal(38,18) (nullable = true)
#  |-- LONGITUDE: decimal(38,18) (nullable = true)
#  |-- OWNER_CODE: decimal(38,18) (nullable = true)
#  |-- OWNER_DESCR: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTY: string (nullable = true)
#  |-- FIPS_CODE: string (nullable = true)
#  |-- FIPS_NAME: string (nullable = true)
#  |-- Shape: decimal(38,18) (nullable = true)

# %%
# Convert Spark DataFrame to a temporary view
df_spark.createOrReplaceTempView("data")

# Extract latitude and longitude columns from the Spark DataFrame
latitude = df_spark.select("LATITUDE").rdd.flatMap(lambda x: x).collect()
longitude = df_spark.select("LONGITUDE").rdd.flatMap(lambda x: x).collect()

# Create a scatter plot
fig, ax = plt.subplots(figsize=(12, 12))
ax.scatter(longitude, latitude, c='green')

# Show the plot
plt.show()

# %%
# Select the latitude and longitude columns
latitude = df_spark.select('LATITUDE').rdd.flatMap(lambda x: x).collect()
longitude = df_spark.select('LONGITUDE').rdd.flatMap(lambda x: x).collect()

# Set up the plot
fig, ax = plt.subplots(figsize=(12, 12))
ax.set_xlim(min(longitude), max(longitude))
ax.set_ylim(min(latitude), max(latitude))

# Add the basemap using contextily
ctx.add_basemap(ax, crs='EPSG:4326', source=ctx.providers.OpenStreetMap.Mapnik)

# Plot the scatter points
ax.scatter(longitude, latitude, c='green', s=1)

# Show the plot
plt.show()

# Close the SparkSession
spark.stop()

# %%
df_spark.select('COUNTY','STATE', 'STAT_CAUSE_DESCR', 'DISCOVERY_DATE', 'DISCOVERY_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS').show()
# Out:
# +------+-----+----------------+--------------------+--------------+--------------------+---------------+
# |COUNTY|STATE|STAT_CAUSE_DESCR|      DISCOVERY_DATE|DISCOVERY_TIME|           FIRE_SIZE|FIRE_SIZE_CLASS|
# +------+-----+----------------+--------------------+--------------+--------------------+---------------+
# |    63|   CA|   Miscellaneous|2453403.500000000...|          1300|0.100000000000000000|              A|
# |    61|   CA|       Lightning|2453137.500000000...|          0845|0.250000000000000000|              A|
# |    17|   CA|  Debris Burning|2453156.500000000...|          1921|0.100000000000000000|              A|
# |     3|   CA|       Lightning|2453184.500000000...|          1600|0.100000000000000000|              A|
# |     3|   CA|       Lightning|2453184.500000000...|          1600|0.100000000000000000|              A|
# |     5|   CA|       Lightning|2453186.500000000...|          1800|0.100000000000000000|              A|
# |    17|   CA|       Lightning|2453187.500000000...|          1800|0.100000000000000000|              A|
# |  null|   CA|  Debris Burning|2453437.500000000...|          1300|0.800000000000000000|              B|
# |  null|   CA|  Debris Burning|2453444.500000000...|          1200|1.000000000000000000|              B|
# |     5|   CA|       Lightning|2453187.500000000...|          1800|0.100000000000000000|              A|
# |    17|   CA|       Lightning|2453188.500000000...|          1830|0.100000000000000000|              A|
# |     5|   CA|       Lightning|2453188.500000000...|          1730|0.100000000000000000|              A|
# |    17|   CA|   Miscellaneous|2453251.500000000...|          1600|0.100000000000000000|              A|
# |     5|   CA|        Campfire|2453276.500000000...|          1200|6.000000000000000000|              B|
# |    17|   CA|       Lightning|2453281.500000000...|          0630|0.200000000000000000|              A|
# |    17|   CA|       Lightning|2453281.500000000...|          0930|0.100000000000000000|              A|
# |     5|   CA|   Equipment Use|2453284.500000000...|          1415|16823.00000000000...|              G|
# |    17|   CA|   Equipment Use|2453291.500000000...|          1618|7700.000000000000...|              G|
# |    17|   CA|  Debris Burning|2453329.500000000...|          2000|0.100000000000000000|              A|
# |    27|   NM|       Lightning|2453160.500000000...|          1030|0.100000000000000000|              A|
# +------+-----+----------------+--------------------+--------------+--------------------+---------------+
# only showing top 20 rows

# %%
df_spark.select('COUNTY','STATE', 'STAT_CAUSE_DESCR', 'DISCOVERY_DATE', 'DISCOVERY_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS').describe().show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +-------+-----------------+-------+----------------+--------------------+------------------+--------------------+---------------+
# |summary|           COUNTY|  STATE|STAT_CAUSE_DESCR|      DISCOVERY_DATE|    DISCOVERY_TIME|           FIRE_SIZE|FIRE_SIZE_CLASS|
# +-------+-----------------+-------+----------------+--------------------+------------------+--------------------+---------------+
# |  count|          1202317|1880465|         1880465|             1880465|            997827|             1880465|        1880465|
# |   mean|43.72427478281645|   null|            null|2453063.657027118...|1453.0143261306819|74.52015833992390...|           null|
# | stddev|41.92782842806354|   null|            null|   2434.573159185869| 405.9609625656342|   2497.598179796961|           null|
# |    min|              001|     AK|           Arson|2448622.500000000...|              0000|0.000010000000000000|              A|
# |    max|          yankton|     WY|       Structure|2457387.500000000...|              2359|606945.0000000000...|              G|
# +-------+-----------------+-------+----------------+--------------------+------------------+--------------------+---------------+

# %%
FIRE_SIZE_CLASS_UNIQUES = df_spark.select('FIRE_SIZE_CLASS').distinct().collect()
for one_row in FIRE_SIZE_CLASS_UNIQUES:
    print (one_row[0])
# Out:
# [Stage 13:>                                                         (0 + 1) / 1]
# F
# E
# B
# D
# C
# A
# G

# %%
df_spark.groupBy('FIRE_SIZE_CLASS').count().show()
# Out:
# [Stage 40:>                                                         (0 + 1) / 1]
# +---------------+------+
# |FIRE_SIZE_CLASS| count|
# +---------------+------+
# |              F|  7786|
# |              E| 14107|
# |              B|939376|
# |              D| 28427|
# |              C|220077|
# |              A|666919|
# |              G|  3773|
# +---------------+------+

# %%
from pyspark.sql import functions as F

df_spark.groupBy('FIRE_SIZE_CLASS').agg(F.avg('FIRE_SIZE')).show()
# Out:
# [Stage 43:>                                                         (0 + 1) / 1]
# +---------------+--------------------+
# |FIRE_SIZE_CLASS|      avg(FIRE_SIZE)|
# +---------------+--------------------+
# |              F|2130.395128422810...|
# |              E|512.8549039420146...|
# |              B|2.146998274939960...|
# |              D|161.8010338723748...|
# |              C|28.53191445355943...|
# |              A|0.118801012820147...|
# |              G|27388.19070278293...|
# +---------------+--------------------+

# %%
df_spark.groupBy('FIRE_SIZE_CLASS').agg(F.avg('FIRE_SIZE')).dtypes
# Out:
# [('FIRE_SIZE_CLASS', 'string'), ('avg(FIRE_SIZE)', 'decimal(38,22)')]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pyspark.sql.functions import col

# Perform the groupBy and aggregation
result_df = df_spark.groupBy('FIRE_SIZE_CLASS').agg(F.avg('FIRE_SIZE')).toPandas()
result_df_ordered = result_df.sort_values(by='FIRE_SIZE_CLASS')
result_df_ordered
# Out:
#   FIRE_SIZE_CLASS                avg(FIRE_SIZE)
# 5               A      0.1188010128201475741432
# 2               B      2.1469982749399601437680
# 4               C     28.5319144535594360158399
# 3               D    161.8010338723748548921800
# 1               E    512.8549039420146026795208
# 0               F   2130.3951284228101721037760
# 6               G  27388.1907027829313543599258

# %%
import matplotlib.pyplot as plt

# Convert the average fire size column to a numeric data type
result_df_ordered['avg(FIRE_SIZE)'] = result_df_ordered['avg(FIRE_SIZE)'].astype(float)

# Plot the histogram with log scale on y-axis
result_df_ordered.plot(x='FIRE_SIZE_CLASS', y='avg(FIRE_SIZE)', kind='bar')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.xlabel('Fire Size Class')
plt.ylabel('Average Fire Size (Log Scale)')
plt.title('Histogram of Average Fire Size by Class')
plt.show()

# %%
result_df
# Out:
#   FIRE_SIZE_CLASS                avg(FIRE_SIZE)
# 0        Letter F   2130.3951284228101721037760
# 1        Letter E    512.8549039420146026795208
# 2        Letter B      2.1469982749399601437680
# 3        Letter D    161.8010338723748548921800
# 4        Letter C     28.5319144535594360158399
# 5        Letter A      0.1188010128201475741432
# 6        Letter G  27388.1907027829313543599258

# %%
df_spark.groupBy('STATE').count().show(truncate=False)
# Out:
# [Stage 100:>                                                        (0 + 1) / 1]
# +-----+------+
# |STATE|count |
# +-----+------+
# |AZ   |71586 |
# |SC   |81315 |
# |LA   |30013 |
# |MN   |44769 |
# |NJ   |25949 |
# |DC   |66    |
# |OR   |61088 |
# |VA   |21833 |
# |RI   |480   |
# |WY   |14166 |
# |KY   |27089 |
# |NH   |2452  |
# |MI   |10502 |
# |NV   |16956 |
# |WI   |31861 |
# |ID   |36698 |
# |CA   |189550|
# |NE   |7973  |
# |CT   |4976  |
# |MT   |40767 |
# +-----+------+
# only showing top 20 rows

# %%
df_spark.select('STATE').distinct().count()
# Out:
# 52

# %%
df_spark.select('STAT_CAUSE_DESCR').distinct().show()
# Out:
# [Stage 115:>                                                        (0 + 1) / 1]
# +-----------------+
# | STAT_CAUSE_DESCR|
# +-----------------+
# |    Miscellaneous|
# |          Smoking|
# |        Lightning|
# |         Campfire|
# |            Arson|
# |   Debris Burning|
# |         Railroad|
# |        Powerline|
# |Missing/Undefined|
# |        Structure|
# |         Children|
# |        Fireworks|
# |    Equipment Use|
# +-----------------+

# %%
df_spark.groupBy('STAT_CAUSE_DESCR').count().show()
# Out:
# [Stage 118:>                                                        (0 + 1) / 1]
# +-----------------+------+
# | STAT_CAUSE_DESCR| count|
# +-----------------+------+
# |    Miscellaneous|323805|
# |          Smoking| 52869|
# |        Lightning|278468|
# |         Campfire| 76139|
# |            Arson|281455|
# |   Debris Burning|429028|
# |         Railroad| 33455|
# |        Powerline| 14448|
# |Missing/Undefined|166723|
# |        Structure|  3796|
# |         Children| 61167|
# |        Fireworks| 11500|
# |    Equipment Use|147612|
# +-----------------+------+

# %%
# Compute the total count of all rows
total_count = df_spark.count()

# Perform the groupBy and aggregation
result_df = df_spark.groupBy('STAT_CAUSE_DESCR').count()
#result_df.show()
# Calculate the percentage
result_df = result_df.withColumn('percentage', (col('count') / total_count) * 100)

# Show the result
result_df.show()
# Out:
# [Stage 150:>                                                        (0 + 1) / 1]
# +-----------------+------+-------------------+
# | STAT_CAUSE_DESCR| count|         percentage|
# +-----------------+------+-------------------+
# |    Miscellaneous|323805| 17.219411156283154|
# |          Smoking| 52869|  2.811485457054505|
# |        Lightning|278468| 14.808464927557813|
# |         Campfire| 76139|  4.048945340647127|
# |            Arson|281455| 14.967308617815275|
# |   Debris Burning|429028| 22.814995227244324|
# |         Railroad| 33455|   1.77908123788531|
# |        Powerline| 14448| 0.7683206015533393|
# |Missing/Undefined|166723|  8.866051747838966|
# |        Structure|  3796|0.20186496425086348|
# |         Children| 61167|  3.252759290920065|
# |        Fireworks| 11500| 0.6115508664080427|
# |    Equipment Use|147612|  7.849760564541216|
# +-----------------+------+-------------------+

# %%
result_df_ordered = result_df.toPandas().sort_values(by='percentage')
result_df_ordered
# Out:
#      STAT_CAUSE_DESCR   count  percentage
# 9           Structure    3796    0.201865
# 11          Fireworks   11500    0.611551
# 7           Powerline   14448    0.768321
# 6            Railroad   33455    1.779081
# 1             Smoking   52869    2.811485
# 10           Children   61167    3.252759
# 3            Campfire   76139    4.048945
# 12      Equipment Use  147612    7.849761
# 8   Missing/Undefined  166723    8.866052
# 2           Lightning  278468   14.808465
# 4               Arson  281455   14.967309
# 0       Miscellaneous  323805   17.219411
# 5      Debris Burning  429028   22.814995

# %%
import matplotlib.pyplot as plt


# Plot the histogram with log scale on y-axis
result_df_ordered.plot(x='STAT_CAUSE_DESCR', y='percentage', kind='bar')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.xlabel('Cause of the fire')
plt.ylabel('Percentage (%)')
plt.title('Cause of the fire in all states')
plt.show()

# %%
df_spark.groupBy('STATE', 'STAT_CAUSE_DESCR').count().show()
# Out:
# [Stage 160:>                                                        (0 + 1) / 1]
# +-----+-----------------+-----+
# |STATE| STAT_CAUSE_DESCR|count|
# +-----+-----------------+-----+
# |   VA|   Debris Burning| 7215|
# |   GA|Missing/Undefined|   10|
# |   DE|        Fireworks|    1|
# |   GA|        Structure|    2|
# |   PA|        Structure|    5|
# |   WV|        Lightning|  265|
# |   CT|    Miscellaneous| 2714|
# |   PR|Missing/Undefined|21821|
# |   ID|         Campfire| 1986|
# |   IN|    Equipment Use|   98|
# |   WY|            Arson|  265|
# |   ND|          Smoking|   90|
# |   MD|   Debris Burning|  837|
# |   VT|         Children|    5|
# |   MT|          Smoking|  885|
# |   CO|         Children|  208|
# |   LA|        Fireworks|   80|
# |   AZ|        Lightning|28776|
# |   PA|         Campfire|  498|
# |   AK|            Arson|  458|
# +-----+-----------------+-----+
# only showing top 20 rows

# %%
ca = df_spark.groupBy('STATE', 'STAT_CAUSE_DESCR').count().filter(df_spark['STATE'] == 'CA')
ca.show()
# Out:
# [Stage 187:>                                                        (0 + 1) / 1]
# +-----+-----------------+-----+
# |STATE| STAT_CAUSE_DESCR|count|
# +-----+-----------------+-----+
# |   CA|        Fireworks|  219|
# |   CA|    Miscellaneous|51943|
# |   CA|   Debris Burning|14318|
# |   CA|        Powerline| 1198|
# |   CA|        Structure|  123|
# |   CA|    Equipment Use|39407|
# |   CA|         Campfire| 9516|
# |   CA|            Arson|19635|
# |   CA|Missing/Undefined|12605|
# |   CA|        Lightning|27000|
# |   CA|          Smoking| 5936|
# |   CA|         Children| 6930|
# |   CA|         Railroad|  720|
# +-----+-----------------+-----+

# %%
type(ca)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
ca_ordered = ca.toPandas().sort_values(by='count')
ca_ordered
# Out:
#    STATE   STAT_CAUSE_DESCR  count
# 4     CA          Structure    123
# 0     CA          Fireworks    219
# 12    CA           Railroad    720
# 3     CA          Powerline   1198
# 10    CA            Smoking   5936
# 11    CA           Children   6930
# 6     CA           Campfire   9516
# 8     CA  Missing/Undefined  12605
# 2     CA     Debris Burning  14318
# 7     CA              Arson  19635
# 9     CA          Lightning  27000
# 5     CA      Equipment Use  39407
# 1     CA      Miscellaneous  51943

# %%
import matplotlib.pyplot as plt


# Plot the histogram with log scale on y-axis
ca_ordered.plot(x='STAT_CAUSE_DESCR', y='count', kind='bar')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.xlabel('Cause of the fire')
plt.ylabel('Percentage (%)')
plt.title('Cause of the fire in CA')
plt.show()

# %%
df_spark.select('STATE').distinct().show()
# Out:
# [Stage 220:>                                                        (0 + 1) / 1]
# +-----+
# |STATE|
# +-----+
# |   AZ|
# |   SC|
# |   LA|
# |   MN|
# |   NJ|
# |   DC|
# |   OR|
# |   VA|
# |   RI|
# |   WY|
# |   KY|
# |   NH|
# |   MI|
# |   NV|
# |   WI|
# |   ID|
# |   CA|
# |   NE|
# |   CT|
# |   MT|
# +-----+
# only showing top 20 rows

# %%
df_spark.groupBy('STATE').count().show()
# Out:
# [Stage 223:>                                                        (0 + 1) / 1]
# +-----+------+
# |STATE| count|
# +-----+------+
# |   AZ| 71586|
# |   SC| 81315|
# |   LA| 30013|
# |   MN| 44769|
# |   NJ| 25949|
# |   DC|    66|
# |   OR| 61088|
# |   VA| 21833|
# |   RI|   480|
# |   WY| 14166|
# |   KY| 27089|
# |   NH|  2452|
# |   MI| 10502|
# |   NV| 16956|
# |   WI| 31861|
# |   ID| 36698|
# |   CA|189550|
# |   NE|  7973|
# |   CT|  4976|
# |   MT| 40767|
# +-----+------+
# only showing top 20 rows

# %%
result_df = df_spark.groupBy('STATE').agg(F.avg('FIRE_SIZE')).toPandas()
result_df_ordered = result_df.sort_values(by='avg(FIRE_SIZE)', ascending=False)
result_df_ordered
# Out:
#    STATE               avg(FIRE_SIZE)
# 46    AK  2509.7791981779957953749124
# 13    NV   531.7206499174333569238028
# 15    ID   372.8904823423619815793776
# 34    NM   170.2343177600192112706121
# 9     WY   169.5235552873076380064944
# 19    MT   154.0345406868300340962053
# 27    WA   142.6974102587055769402918
# 6     OR   137.7161041448402304871661
# 50    UT   133.9276276325467860048820
# 17    NE   121.3343481625486015301643
# 43    KS   120.2416005473739085103610
# 0     AZ    77.9018374261727153354008
# 48    OK    74.7586741136474016512870
# 39    TX    68.9068399038170411418030
# 16    CA    67.2427252545502505937167
# 44    CO    53.9365017419562607957373
# 37    SD    50.7336369318218518877370
# 45    FL    49.1546532815944870985254
# 10    KY    37.4650516813466720809185
# 23    DE    28.2669590643274853801170
# 28    ND    27.1434267482402473521479
# 3     MN    27.0411539236972011883223
# 40    WV    26.2498770883598124459416
# 24    MO    25.5960419428507770289088
# 51    HI    25.5443153107630116220313
# 2     LA    22.0245864451071202478926
# 22    MD    18.5752429596907785753727
# 35    IA    17.2936535074987905176584
# 47    AR    16.0727609515838676057228
# 7     VA    15.6481390551000778637842
# 33    TN    15.6208640948192848430378
# 29    MS    14.3314880726997349488830
# 30    AL    13.8282297581493165096398
# 12    MI    13.3526408303180346600647
# 25    IL     9.8012526858616244091104
# 41    GA     9.4154522793677864828534
# 31    IN     8.2568589132507149666349
# 32    OH     6.8795214141994826099454
# 1     SC     6.6613311809629219701162
# 20    NC     6.5648917566972510042911
# 36    PA     6.2822274482323232323232
# 49    PR     6.2808939812508491463249
# 4     NJ     5.0854960114069906354773
# 21    VT     3.4133464912280701754386
# 14    WI     2.7831915525878032704560
# 42    MA     2.3323419649657273419650
# 18    CT     2.2595076366559485530547
# 26    ME     1.8673490494296577946768
# 11    NH     1.5750436378466557911909
# 8     RI     1.1716875000000000000000
# 38    NY     1.1595396663286756522814
# 5     DC     0.4924242424242424242424

# %%
result_df = df_spark.groupBy('STATE', 'FIRE_SIZE_CLASS').count().toPandas()
result_df[result_df['STATE'] == 'CA'].sort_values(by='count', ascending=False)
# Out:
#     STATE FIRE_SIZE_CLASS  count
# 139    CA               A  98309
# 256    CA               B  76942
# 319    CA               C   9825
# 8      CA               D   2137
# 68     CA               E   1187
# 157    CA               F    756
# 239    CA               G    394

# %%
df_spark.select('COUNTY').distinct().show(n=1000)
# Out:
# [Stage 271:>                                                        (0 + 1) / 1]
# +--------------------+
# |              COUNTY|
# +--------------------+
# |           Petroleum|
# |                Utah|
# |      East Feliciana|
# |           Worcester|
# |              Aitkin|
# |               Bucks|
# |              Grimes|
# |               Tyler|
# |             Hanover|
# |            Thurston|
# |             HANCOCK|
# |          CUMBERLAND|
# |             JOHNSON|
# |             lATIMER|
# |               ADAIR|
# |               OSAGE|
# |Chattooga           |
# |            OKANOGAN|
# |       Unicoi County|
# |                 125|
# |          Deer Lodge|
# |             Gilliam|
# |               Izard|
# |               Pasco|
# |            Montcalm|
# |          Charleston|
# |            Angelina|
# |           Oktibbeha|
# |             Shannon|
# |            REYNOLDS|
# |               EMMET|
# |            Island C|
# |               ATOKA|
# |Randolph            |
# |              YAKIMA|
# |LUCE             ...|
# |            PONTOTOC|
# |     Woodward County|
# |              Hawaii|
# |               Ferry|
# |            Harrison|
# |            McDowell|
# |          Dickinson |
# |               KIOWA|
# |              CONWAY|
# |     Dare Bomb Range|
# |               STory|
# |              Cayuga|
# |                  51|
# |                   7|
# |              Plumas|
# |                Juab|
# |                Rich|
# |               Scott|
# |            Calloway|
# |           Robertson|
# |              Wilson|
# |          Georgetown|
# |              McMinn|
# |          Tishomingo|
# |           MARQUETTE|
# |           Merrimack|
# |                YUMA|
# |           Cumberlin|
# |                COOS|
# |            FENTRESS|
# |         KING GEORGE|
# |             RUSSELL|
# |Atkinson            |
# |Macon               |
# |                  TC|
# |         pennington |
# |             LOWNDES|
# |              Ulster|
# |            Hodgeman|
# |      El Paso County|
# |           Clackamas|
# |               Kings|
# |             Baldwin|
# |          Tangipahoa|
# |              Tensas|
# |           Brunswick|
# |              Chowan|
# |           Granville|
# |               Lucas|
# |           Pittsburg|
# |              Castro|
# |           Goochland|
# |             Braxton|
# |            McDOWELL|
# |              PHELPS|
# |              FULTON|
# |               Marin|
# |Dade                |
# |Newton              |
# |                  SC|
# |                 169|
# |                 205|
# |              Monroe|
# |             Venango|
# |                Dent|
# |               LYON |
# |    Geary County, KS|
# |          LACKAWANNA|
# |          Litchfield|
# |Candler             |
# |Butts               |
# |                 day|
# |               Lyman|
# |              Graham|
# |               Jones|
# |            Glascock|
# |                Boyd|
# |              Arenac|
# |                Real|
# |            Sterling|
# |   SACRAMENTO/AMADOR|
# |              Bremer|
# |           McDonough|
# |       PRINCE EDWARD|
# |Terrell             |
# |          EVANGELINE|
# |              Queens|
# |       Benton County|
# |       Garvin County|
# |                  15|
# |            Kittitas|
# |              Conway|
# |             Bossier|
# |             Lenawee|
# |              Waller|
# |               CEDAR|
# |              COLFAX|
# |           Palo Alto|
# |           MERRIMACK|
# |            COCONINO|
# |              MURRAY|
# |Meriwether          |
# |Talbot              |
# |                  54|
# |                 155|
# |              Marion|
# |            Crawford|
# |     Prince George's|
# |      N.  WORCHESTER|
# |               Pepin|
# |             Lewis C|
# |            cheshire|
# |                Inyo|
# |             Millard|
# |             Calhoun|
# |              Elbert|
# |              Potter|
# |          Deaf Smith|
# |                Dane|
# |            Okfuskee|
# |              WESTON|
# |             Autauga|
# |             CHESTER|
# |           Spokane C|
# |                  SB|
# |              LASSEN|
# |              McCook|
# |             ASHLAND|
# |       Madera County|
# |              Walton|
# |                Ohio|
# |               EMERY|
# |         LEAVENWORTH|
# |             COCHISE|
# |                  BW|
# |                  MN|
# |      Bourbon County|
# |                  11|
# |                 101|
# |              Sonoma|
# |            Gallatin|
# |      West Feliciana|
# |            Richland|
# |            Isabella|
# |            Mahnomen|
# |           Allendale|
# |               Garza|
# |           Marinette|
# |                 009|
# |             Montour|
# |               WHITE|
# |            Gilliam |
# |           GOOCHLAND|
# |Fayette             |
# |           bon homme|
# |       Saint Charles|
# |              Roseau|
# |             Harding|
# |             Latimer|
# |            Hudspeth|
# |           Snohomish|
# |           Hampshire|
# |             Neshoba|
# |              Bureau|
# |Madison             |
# |Webster             |
# |           BOLLINGER|
# |             SIMPSON|
# |           Faribault|
# |                Napa|
# |                Coos|
# |           Josephine|
# |              Ottawa|
# |               Davie|
# |               Dewey|
# |            Eastland|
# |            Hansford|
# |            KENNEBEC|
# |    Snohomish County|
# |         Bartholomew|
# |               RILEY|
# |                HOCK|
# |             MONTOUR|
# |               UNION|
# |           SEBASTIAN|
# |Morgan              |
# |              Jersey|
# |             HARDING|
# |           KINGSBURY|
# |    Riverside County|
# |                  69|
# |                  29|
# |                 419|
# |                 073|
# |                 065|
# |               Delta|
# |               Ouray|
# |              Oneida|
# |               Piute|
# |            Franklin|
# |                Taos|
# |              Sumter|
# |              Coweta|
# |          St. Landry|
# |              Lenoir|
# |     Kittitas County|
# | Pend Oreille County|
# |       SANTA BARBARA|
# |           ARMSTRONG|
# |       LAKE - SONOMA|
# |                  PS|
# |              PIERCE|
# |            melllete|
# |          Barnstable|
# |            BonHomme|
# |              Dallas|
# |           Concordia|
# |                  42|
# |               CROOK|
# |      Calhoun County|
# |             belknap|
# |              GIBSON|
# |               Dawes|
# |          Grand Isle|
# |     Scotland County|
# |                  87|
# |                  73|
# |             Yavapai|
# |               Latah|
# |            Guilford|
# |        Chesterfield|
# |            Brewster|
# |              Brooke|
# |            DUCHESNE|
# |                RENO|
# |         SANTA CLARA|
# |           Ascension|
# |              BLAINE|
# |            Bradford|
# |               Clare|
# |             Oakland|
# |               Mayes|
# |          Lackawanna|
# |              Kitsap|
# |                Tate|
# |      Cowlitz County|
# |                 087|
# |             CHOCTAW|
# |      Prince Georges|
# |        PRESQUE ISLE|
# |          Okanogan C|
# |       POTTAWATTOMIE|
# |             HENRICO|
# |Jones               |
# |                  WC|
# |                  64|
# |              haakon|
# |             Stanely|
# |       Moffat County|
# |        Dawes County|
# |                   3|
# |                 053|
# |               Davis|
# |              Wilcox|
# |               Lamar|
# |                Bell|
# |             Daviess|
# |           Edgecombe|
# |               Irion|
# |              SEVIER|
# |                YUBA|
# |              CENTRE|
# |            CHIPPEWA|
# |       Walla Walla C|
# |            CLEBURNE|
# |Taylor              |
# |            MONTEREY|
# |        CONTRA COSTA|
# |             Chemung|
# |                 113|
# |            Treutlen|
# |            Cherokee|
# |             Haywood|
# |          Sequatchie|
# |            Jim Hogg|
# |     Petersburg City|
# |                  30|
# |             LATIMER|
# |              DeKalb|
# |             OAKLAND|
# |             Grafotn|
# |                WELD|
# |            sullivan|
# |            TAZEWELL|
# |Monroe              |
# |               WORTH|
# |               GLENN|
# |               JONES|
# |            campbell|
# |             Clatsop|
# |         Leavenworth|
# |             Granite|
# |              Beaver|
# |               Huron|
# |            Fillmore|
# |               Craig|
# |                  34|
# |          SANTA ROSA|
# |               CADDO|
# |Walla-Walla/Columbia|
# |Troup               |
# |                  JF|
# |ARENAC           ...|
# |             Rutland|
# |        Geary County|
# |        Otero County|
# |            Molokaii|
# |                 133|
# |              Madera|
# |              Sevier|
# |                Cobb|
# |          Charlevoix|
# |             Wexford|
# |              Tipton|
# |                Webb|
# |              Alcorn|
# |      Chester County|
# |               Sioux|
# |             Delware|
# |           CALAVERAS|
# |Quitman             |
# |       Fall River co|
# |               Pinal|
# |            Siskiyou|
# |              Moffat|
# |              Owyhee|
# |              Teller|
# |               Floyd|
# |           Christian|
# |             Grayson|
# |            Houghton|
# |              Yancey|
# |       Prince George|
# |       Kitsap County|
# |                 Ray|
# |               GRANT|
# |                 028|
# |       Dillon County|
# |          Mc Intosh |
# |Bryan South         |
# |Carroll             |
# |            Arapahoe|
# |                  59|
# |            Arkansas|
# |              Chicot|
# |                Levy|
# |            Beaufort|
# |              Oregon|
# |              Copiah|
# |            CAMPBELL|
# |              Dickey|
# |               BUTTE|
# |        Jones & Linn|
# |            Pierce C|
# |Bleckley            |
# |Harris              |
# |Houston             |
# |BENZIE           ...|
# |              VINTON|
# |               IDAHO|
# |                hand|
# |     Dallas & Camden|
# |                 139|
# |              Blaine|
# |            Phillips|
# |                Knox|
# |           Cheboygan|
# |          Otter Tail|
# |             Caswell|
# |        King William|
# |             Raleigh|
# |              AMADOR|
# |Rav.,Miss. & Granite|
# |                LUCE|
# |             Ventura|
# |            POWHATAN|
# |             BENNETT|
# |    Clark County, KS|
# |              Hendry|
# |               Banks|
# |             Spencer|
# |              Oxford|
# |               Falls|
# |            Accomack|
# |    Klickitat County|
# |              Barnes|
# |              EMMONS|
# |             Bullock|
# |         SUSQUEHANNA|
# |           MIDDLESEX|
# |            SCOTLAND|
# |MIDLAND          ...|
# |            El Paso |
# |                Luna|
# |              Orange|
# |             Hocking|
# |              Barron|
# |                   8|
# |      Ste. Genevieve|
# |    Edgefield County|
# |         CATTARAUGUS|
# |           WASHTENAW|
# |             CARROLL|
# |              CANNON|
# |                DYER|
# |          COLUMBIANA|
# |      Saint Francois|
# |              MOHAVE|
# |               Barry|
# |       Collingsworth|
# |               Hardy|
# |             STEUBEN|
# |Dodge               |
# |              ANDREW|
# |CHIPPEWA         ...|
# |CRAWFORD         ...|
# |                LUCA|
# |            Minidoka|
# |         Sweet Grass|
# |              Searcy|
# |             Alachua|
# |               Gates|
# |           Middlesex|
# |               Berks|
# |             Hampton|
# |               Gregg|
# |              Goliad|
# |       Pueblo County|
# |               MACON|
# |      Kershaw County|
# |Hall                |
# |                  CN|
# |                  LM|
# |                INYO|
# |                YOLO|
# |                HARR|
# |         charles mix|
# |                  28|
# |                 203|
# |         Los Angeles|
# |              Carbon|
# |              Harney|
# |               Peach|
# |             Benewah|
# |               Adair|
# |           Ontonagon|
# |             Kendall|
# |           Pleasants|
# |                YORK|
# |                  22|
# |           Covington|
# |Habersham           |
# |            MONITEAU|
# |ANTRIM           ...|
# |  Stanton County, KS|
# |           MUSKINGUM|
# |                 199|
# |            Campbell|
# |          Palm Beach|
# |          Rutherford|
# |            Crockett|
# |                Jack|
# |               YATES|
# |             ALLEGAN|
# |            DAVIDSON|
# |Telfair             |
# |           CALCASIEU|
# |MACKINAC         ...|
# |               Upton|
# |             Steuben|
# |     Humboldt County|
# |           Multnomah|
# |            Gwinnett|
# |              Alcona|
# |            Chippewa|
# |           Roscommon|
# |               Swain|
# |           Fairfield|
# |           Van Zandt|
# |             WASATCH|
# |                 061|
# |              CAMDEN|
# |                 093|
# |            Macoupin|
# |        hillsborough|
# |             WEAKLEY|
# |              Norton|
# |               SURRY|
# |IRON             ...|
# |              PLUMAS|
# |             PERKINS|
# |             LINCLON|
# |             LaMoure|
# |            Williams|
# |                  85|
# |               Curry|
# |                Gulf|
# |             Fayette|
# |              Bartow|
# |              Otsego|
# |                Pine|
# |                Rock|
# |             Cowley |
# |               BARRY|
# | Humboldt / Pershing|
# |           STRAFFORD|
# |             AUGUSTA|
# |Lincoln             |
# |           Penninton|
# |       Gallia County|
# |Santa Barbara County|
# |                  35|
# |               Power|
# |               Smith|
# |            Fauquier|
# |                  16|
# |        Tallahatchie|
# |     Berkeley County|
# |            MACKINAC|
# |         Klickitat C|
# |                Rosa|
# |            OUACHITA|
# |Colquitt            |
# |                 RAY|
# |                JEFF|
# |                  52|
# |                 171|
# |                 027|
# |            Okanogan|
# |            Boundary|
# |             Wallowa|
# |            Haralson|
# |             Emanuel|
# |               Erath|
# |      Pacific County|
# |  Spartanburg County|
# |             LUZERNE|
# |              EUREKA|
# |               Dukes|
# |            Doniphan|
# |         Utah County|
# |                 187|
# |                 037|
# |          Sacramento|
# |              Citrus|
# |               Rowan|
# |        Presque Isle|
# |             SANPETE|
# |             CAMERON|
# |         Cerro Gordo|
# |              TEHAMA|
# |             Stanley|
# |              HOLMES|
# |             Bennett|
# |                  71|
# |                 069|
# |               Allen|
# |             Allegan|
# |   Lake of the Woods|
# |             McClain|
# |           Culberson|
# |             Cochran|
# |            Tazewell|
# |               Texas|
# |               Taney|
# |            Okmulgee|
# |           CHEBOYGAN|
# |           Blackhawk|
# |             TRINITY|
# |                GUER|
# |                 013|
# |                Lake|
# |             Meagher|
# |              Camden|
# |            Edmonson|
# |             Calvert|
# |              Carver|
# |    Wahkiakum County|
# |               ROUTT|
# |              DESOTO|
# |               AMITE|
# |           SAN MATEO|
# |Gordon              |
# |                  47|
# |                  99|
# |                 223|
# |                 195|
# |                Drew|
# |            Burleson|
# |              Zavala|
# |          Eau Claire|
# |               Creek|
# |         SCHOOLCRAFT|
# |                TUSC|
# |              DEKALB|
# |              HOWARD|
# |         ST FRANCOIS|
# |               Payne|
# |             merceer|
# |          Stanislaus|
# |              Platte|
# |                Hall|
# |           Guadalupe|
# |             Kaufman|
# |              Morton|
# |            BRAZORIA|
# |      GRAND TRAVERSE|
# |Spalding            |
# |              CHELAN|
# |           BON HOMME|
# |            La Moure|
# |               Trego|
# |                 107|
# |                 110|
# |              Mohave|
# |           Calaveras|
# |           Roosevelt|
# |             Hidalgo|
# |             Webster|
# |              Gilmer|
# |           Pendleton|
# |            Davidson|
# |             Mifflin|
# |             Pickett|
# |            Lampasas|
# |               SIOUX|
# |       Adair/Guthrie|
# |              CHICOT|
# |LEELANAU         ...|
# |           Cleveland|
# |            Pinellas|
# |           Red River|
# |            Hertford|
# |               Meigs|
# |             Weakley|
# |            Victoria|
# |        San Patricio|
# |              STOREY|
# |             Colbert|
# |                Dale|
# |             CHAFFEE|
# |              Nowata|
# |                  HR|
# |          PENNINGTON|
# |              jeauld|
# |                null|
# |           San Diego|
# |         Musselshell|
# |              Miller|
# |               Meade|
# |        Queen Anne's|
# |             Kershaw|
# |          Lee County|
# |          Columbia C|
# |Bulloch             |
# |Pickens             |
# |Banks               |
# |Oconee              |
# |              OREGON|
# |               lyman|
# |            Mellette|
# |        Perry County|
# |           El Dorado|
# |              Saline|
# |          Montgomery|
# |           Chattooga|
# |            Renville|
# |              Mercer|
# |                Hale|
# |        Grays Harbor|
# |             MIFFLIN|
# |           MENOMINEE|
# |           Cowlitz C|
# |        PITTSYLVANIA|
# |               Slope|
# |            Tompkins|
# |                 179|
# |                 067|
# |                 031|
# |              Pitkin|
# |               Union|
# |           Highlands|
# |             Kittson|
# |           Pipestone|
# |             Coryell|
# |            Schuyler|
# |               FLOYD|
# |               KINGS|
# |      PRINCE_WILLIAM|
# |Berrien             |
# |       Yukon-Koyukuk|
# |         Trempealeau|
# |              Tunica|
# |             Nodaway|
# |          New Madrid|
# |                 075|
# |          Jones/Linn|
# |            SEQUOYAH|
# |            ATCHISON|
# |         HUTCHIINSON|
# |      Russell County|
# |          Santa Cruz|
# |          Santa Rosa|
# |             Lumpkin|
# |              Wright|
# |           Alleghany|
# |            Chambers|
# |              Yoakum|
# |              Howell|
# |              MERCER|
# |              OSWEGO|
# |          SCHUYLKILL|
# |             Trimble|
# |          WILLIAMSON|
# |           ROBERTSON|
# |Walker              |
# |               Wells|
# |                 221|
# |                 081|
# |             Trinity|
# |              Albany|
# |            Duchesne|
# |              Walker|
# |           Dickinson|
# |            Keweenaw|
# |            Muskogee|
# |       San Augustine|
# |          RIO ARRIBA|
# |     Marlboro County|
# |              ALCONA|
# |             BROWARD|
# |           EL DORADO|
# |              SOLANO|
# |               spink|
# |                  43|
# |             Yamhill|
# |            Woodruff|
# |                Hyde|
# |           Hunterdon|
# |             Wagoner|
# |               Foard|
# |          Rockbridge|
# |               Amite|
# |            St Johns|
# |                EDDY|
# |             MADISON|
# |     Florence County|
# |             HOUSTON|
# |               CREEK|
# |Floyd               |
# |Baldwin             |
# |Lee                 |
# |                  FY|
# |  Musselshell County|
# |                   5|
# |              Bonner|
# |              Fulton|
# |            Spalding|
# |            Florence|
# |              Sumner|
# |              Brazos|
# |            CRAWFORD|
# |         MONTMORENCY|
# |        Fulton South|
# |           RED RIVER|
# |        KING WILLIAM|
# |Johnson             |
# |            PEMISCOT|
# |CLARE            ...|
# |            Harding |
# |        Osage County|
# |                  31|
# |                 163|
# |                 015|
# |             Conejos|
# |          Columbiana|
# |             Bamberg|
# |           Bon Homme|
# |           Limestone|
# |            Costilla|
# |             HAMBLEN|
# |           TROUSDALE|
# |               MAYES|
# |            FLUVANNA|
# |             Pembina|
# |               Boise|
# |              Becker|
# |             Ashland|
# |              Aurora|
# |               Cocke|
# |               MASON|
# |                 006|
# |               ADAMS|
# |            MONTCALM|
# |            CHESHIRE|
# |Lumpkin             |
# |Lamar               |
# |Tift                |
# |                  CV|
# |               MODOC|
# |           Box Elder|
# |                Cook|
# |              Barren|
# |              McLean|
# |             De Witt|
# |           JEFFERSON|
# |          SANTA CRUZ|
# |Brantley            |
# |                  LR|
# |                FULT|
# |      Harding County|
# |          pennington|
# |           catahoula|
# |              Valley|
# |                 Nye|
# |            Cheyenne|
# |             Berrien|
# |              Harlan|
# |              Antrim|
# |           St. Louis|
# |              Norman|
# |          Blue Earth|
# |               Miner|
# |                  18|
# |              Cowley|
# |                Gove|
# |             DOUGLAS|
# |          CHAUTAUQUA|
# |               ALGER|
# |             Mason C|
# |             SHARKEY|
# |            Rockland|
# |             Genesee|
# |           Coshocton|
# |            Fentress|
# |               Titus|
# |              Oldham|
# |              TOOELE|
# |               ROANE|
# |   Greenville County|
# |             MECOSTA|
# |              BENZIE|
# |               GILES|
# |                Lee |
# |Catoosa             |
# |Dooly               |
# |                  70|
# |             TUSCOLA|
# |             HOCKING|
# |            Converse|
# |                Yell|
# |               Aiken|
# |               Rains|
# |              Reagan|
# |          Schleicher|
# |                Lynn|
# |          Monongalia|
# |             McHenry|
# |                  GV|
# |               TANEY|
# |              TURNER|
# |              Emmett|
# |            Saratoga|
# |         Santa Clara|
# |             Clayton|
# |             Candler|
# |        Anne Arundel|
# |              Ramsey|
# |              Person|
# |             Sampson|
# |                King|
# |             De Kalb|
# |           Meade, KS|
# |                 LAC|
# |         SCHENECTADY|
# |            SAGUACHE|
# |          FALL RIVER|
# |         Juab County|
# |           Hempstead|
# |          Perquimans|
# |              Hudson|
# |            Guernsey|
# |         Susquehanna|
# |            Live Oak|
# |             Forrest|
# |               Hinds|
# |               HARDY|
# |               PERRY|
# |                 019|
# |             BLEDSOE|
# |           Codington|
# |                Holt|
# |     Kenai Peninsula|
# |     Richmond County|
# |                  61|
# |                  27|
# |            Pershing|
# |               Cache|
# |              Itasca|
# |             Dauphin|
# |            Sullivan|
# |             Loudoun|
# |      Whatcom County|
# |              WARREN|
# |      Gwinnett North|
# |          Winneshiek|
# |               CROSS|
# |Miller              |
# |KALKASKA         ...|
# |             YAVAPAI|
# |                  75|
# |              Weston|
# |              Goshen|
# |        Independence|
# |               Desha|
# |           McCormick|
# |            Comanche|
# |             Hockley|
# |               WALDO|
# |                PIKE|
# |              blount|
# |           MISSAUKEE|
# |           Hillsboro|
# |              HARDIN|
# |            Chelan C|
# |         MECKLENBURG|
# |Worth               |
# |                  CL|
# |            Mcintosh|
# |           Melllette|
# |            BpnHomme|
# |             Wheeler|
# |             Sanpete|
# |            Sublette|
# |           Gilchrist|
# |           Dougherty|
# |                Winn|
# |            Allegany|
# |            Buncombe|
# |          Burlington|
# |             Hawkins|
# |             Whatcom|
# |               Vilas|
# |              Cooper|
# |   Potawatomi Co, KS|
# |        FOUND DU LAC|
# |     Cherokee County|
# |            ROCKLAND|
# |               WYTHE|
# |Upson               |
# |Chatham             |
# |            STODDARD|
# |            MARIPOSA|
# |           Brookings|
# +--------------------+
# only showing top 1000 rows

# %%
ideas to consider for ML

1. Given state, county, cause of fire, date, can I predict the fire size class? (the problem is classification)
2. Given state, county, cause of fire, date, can I predict the fire size ? (the problem is regression)
3. Given time, location, and size can I predict the cause of the fire? is it a function of seasons?
